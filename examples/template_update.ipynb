# %% [markdown]
# # ITR Data Template Update
#
# This notebooks help reorganize a Version 1 Sample Data Template into Version 2 format (which splits financial and emissions reporting across two sheets).
#
# The **Sample Data template** provides both a *Read me* sheet and sheet of data dictionary *Definitions*, as well as three input data sheets:
# * ITR financial data: The fundamental financial data of companies, listed by security instrument as company id
# * ITR emissions and production data: The emissions, and production data of companies, listed by security instrument as company id
# * ITR target input data: Short-term Emissions or Intensity reduction targets and Net-Zero attainment target dates, listed by company id
# * Portfolio: A list of positions and investment value amounts
#
# The user may choose **Benchmark Data** that forecasts intensity reductions expected from 2020-2050 by region and sector.  By default we use the OECM benchmark, but two TPI benchmarks are also available.  In all three cases we use the same projections for production grwoth forecasts.  We also use the same global carbon budget and TCRE multipliers for all benchmarks.
#
# After scoring the portfolio, the portfolio is copied to the local file *data_dump.xlsx* which can be downloaded for further analysis.
#
# This notebook also outputs an **enhanced portfolio** (with temperature scores), can be aggregated using various weighting methods to gain additional portfolio alignment insights.
#
# Please enjoy learning how the ITR tool works by following the computations performed by this Jupyter Notebook!

# %% [markdown]
# ## Getting started
# Make sure you are running the notebook with the requirements installed available in the example folder.
#
# If you see errors when attempting to load the ITR modules, go to the top-level ITR directory, activate the `itr_env` conda environment (using `conda activate itr_env` and execute the command `pip install -e .`.  Then try again, or hit the <i class="fas fa-forward"></i> button above.

# %%
import os
import sys
import shutil
import warnings

import pandas as pd
import numpy as np
from math import log10

import openpyxl
from openpyxl.workbook import Workbook
from openpyxl.worksheet.dimensions import ColumnDimension, DimensionHolder
from openpyxl.styles import Alignment, Border, Font, PatternFill, Side
from openpyxl.styles.colors import Color
from openpyxl.cell import Cell
from openpyxl.utils import get_column_letter

from itertools import chain
from datetime import date, datetime

# %% [markdown]
# ## Download/load the sample template data
#
# We have prepared sample data from public sources for you to be able to run the tool as it is to familiarise yourself with how it works. To use your own data; please check out to the [Data Template Requirements](https://github.com/os-c/ITR/blob/main/docs/DataTemplateRequirements.rst) section of the technical documentation for more details on data requirements and formatting.
#
# *The sample data may contain estimates, simplifications, and recategorizations.  It is intended to be generally representative, but not authoritative, and should not be relied upon to make investment decisions.*

# %% [raw]
# import urllib.request
# from github import Github
#
# # Create a Github instance with an access token.
# # Use your shell's `export` command to inject your token into the GITHUB_TOKEN environment variable before starting this jupyter-lab instance.
# gh = Github(os.environ['GITHUB_TOKEN'])
#
# # Get repository by name and select the proper branch
# repo = gh.get_repo("os-climate/ITR").get_branch(branch="develop")
#
# if not os.path.isdir("data"):
#     os.mkdir("data")
#
# for filename in ['data/20220927 ITR Tool Sample Data.xlsx' ]:
#     if not os.path.isfile(filename):
#         # Get a specific content file:
#         contents = repo.get_contents(f"examples/{filename}")
#
#         # Donwnload file form ContenFile object info:
#         urllib.urlretrieve(contents.download_url, filename)

# %%
# Change these to your filenames

template_data_path_v1 = "data/20220927 ITR Tool Sample Data.xlsx"
template_data_path_v2 = "data/20220927 ITR V_2 Sample Data.xlsx"

# %% [markdown]
# We copy the original template file to its new version name; this allows us to preserve formatting information and add new pages easily using `openpyxl`

# %%
shutil.copyfile(src=template_data_path_v1, dst=template_data_path_v2)
xlsx_writer = pd.ExcelWriter(template_data_path_v2, mode='a', engine='openpyxl') # append mode allows us to add a new sheet
wb_xlsx = xlsx_writer.book
wb_data = pd.read_excel(template_data_path_v2, sheet_name=['ITR input data'])

# %% [markdown]
# Split the fundamental data into financial and emissions/production data

# %%
index_cols = ['company_name', 'company_lei', 'company_id']
itr_sheet = wb_data['ITR input data'] # .set_index(index_cols)
itr_sheet.report_date = itr_sheet.apply(lambda x: x.report_date if isinstance(x.report_date, datetime) else date(int(x.report_date), 12, 31), axis=1).copy()
all_cols = itr_sheet.columns
scopes = ['s1', 's2', 's1s2', 's3']

financial_cols = ['country', 'region', 'sector', 'exposure', 'currency', 'report_date', 'market_cap', 'revenue', 'ev', 'evic', 'assets']
df = itr_sheet.set_index(index_cols)[financial_cols]
df.insert(df.columns.get_loc('currency')+1, 'fx_quote', '')
df.insert(df.columns.get_loc('currency')+2, 'fx_rate', 1.0)
df.region = df.region.map(lambda x: '' if x is np.nan else x)
financial_df = df
display(financial_df)
# Out:
#                                                                     country  \
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059      US
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007      US
# Alliant Energy                    5493009ML300G373MZ12 US0188021085      US
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024      US
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017      US
# ...                                                                     ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060      US
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026      US
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008      US
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622      GB
# CBRE                              52990016II9MJ2OSWA10 US12504L1098      US
#
#                                                                             region  \
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007  North America
# Alliant Energy                    5493009ML300G373MZ12 US0188021085  North America
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024  North America
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017  North America
# ...                                                                            ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060  North America
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026  North America
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008  North America
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622
# CBRE                              52990016II9MJ2OSWA10 US12504L1098
#
#                                                                                      sector  \
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059   Electricity Utilities
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007   Electricity Utilities
# Alliant Energy                    5493009ML300G373MZ12 US0188021085   Electricity Utilities
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024   Electricity Utilities
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017   Electricity Utilities
# ...                                                                                     ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060   Electricity Utilities
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026                   Steel
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008   Electricity Utilities
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622  Construction Buildings
# CBRE                              52990016II9MJ2OSWA10 US12504L1098    Commercial Buildings
#
#                                                                     exposure  \
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059   equity
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007   equity
# Alliant Energy                    5493009ML300G373MZ12 US0188021085   equity
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024   equity
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017   equity
# ...                                                                      ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060   equity
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026   equity
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008   equity
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622   equity
# CBRE                              52990016II9MJ2OSWA10 US12504L1098   equity
#
#                                                                     currency  \
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059      USD
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007      USD
# Alliant Energy                    5493009ML300G373MZ12 US0188021085      USD
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024      USD
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017      USD
# ...                                                                      ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060      USD
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026      USD
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008      USD
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622      USD
# CBRE                              52990016II9MJ2OSWA10 US12504L1098      USD
#
#                                                                     fx_quote  \
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007
# Alliant Energy                    5493009ML300G373MZ12 US0188021085
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017
# ...                                                                      ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622
# CBRE                              52990016II9MJ2OSWA10 US12504L1098
#
#                                                                      fx_rate  \
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059      1.0
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007      1.0
# Alliant Energy                    5493009ML300G373MZ12 US0188021085      1.0
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024      1.0
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017      1.0
# ...                                                                      ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060      1.0
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026      1.0
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008      1.0
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622      1.0
# CBRE                              52990016II9MJ2OSWA10 US12504L1098      1.0
#
#                                                                     report_date  \
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059  2020-12-31
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007  2019-12-31
# Alliant Energy                    5493009ML300G373MZ12 US0188021085  2019-12-31
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024  2019-12-31
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017  2019-12-31
# ...                                                                         ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060  2019-12-31
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026  2019-12-31
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008  2019-12-31
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622  2021-12-31
# CBRE                              52990016II9MJ2OSWA10 US12504L1098  2021-12-31
#
#                                                                        market_cap  \
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059  9.420000e+09
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007  4.285300e+09
# Alliant Energy                    5493009ML300G373MZ12 US0188021085  1.160000e+10
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024  1.837877e+10
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017  4.349186e+10
# ...                                                                           ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060  2.630000e+10
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026  1.633377e+09
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008  3.062935e+10
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622  2.260000e+09
# CBRE                              52990016II9MJ2OSWA10 US12504L1098  3.631000e+10
#
#                                                                           revenue  \
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059  1.018900e+10
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007  1.240500e+09
# Alliant Energy                    5493009ML300G373MZ12 US0188021085  3.647700e+09
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024  5.910000e+09
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017  1.556140e+10
# ...                                                                           ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060  7.523100e+09
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026  3.759556e+09
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008  1.152900e+10
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622  9.690000e+09
# CBRE                              52990016II9MJ2OSWA10 US12504L1098  2.774000e+10
#
#                                                                                ev  \
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059  8.652000e+09
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007  5.829800e+09
# Alliant Energy                    5493009ML300G373MZ12 US0188021085  1.850360e+10
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024  2.780477e+10
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017  7.341706e+10
# ...                                                                           ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060  3.812080e+10
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026  2.294114e+09
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008  5.060835e+10
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622  1.810000e+09
# CBRE                              52990016II9MJ2OSWA10 US12504L1098  3.784000e+10
#
#                                                                              evic  \
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059  9.681000e+09
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007  5.899100e+09
# Alliant Energy                    5493009ML300G373MZ12 US0188021085  1.851990e+10
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024  2.782077e+10
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017  7.366386e+10
# ...                                                                           ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060  3.815830e+10
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026  2.386477e+09
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008  5.085635e+10
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622  2.920000e+09
# CBRE                              52990016II9MJ2OSWA10 US12504L1098  3.903000e+10
#
#                                                                            assets
# company_name                      company_lei          company_id
# AES Corp.                         2NUNNB7D43COUIRE5295 US00130H1059  3.364800e+10
# ALLETE, Inc.                      549300NNLSIMY6Z8OT86 US0185223007  5.482800e+09
# Alliant Energy                    5493009ML300G373MZ12 US0188021085  1.670070e+10
# Ameren Corp.                      XRZQ5S7HYJFPHJ78L959 US0236081024  2.893300e+10
# American Electric Power Co., Inc. 1B4S6S7G0TW5EE83BO58 US0255371017  7.589230e+10
# ...                                                                           ...
# WEC Energy Group                  549300IGLYTZUK3PVP70 US92939U1060  3.495180e+10
# WORTHINGTON INDUSTRIES INC        1WRCIANKYOIK6KYE5E82 US9818111026  2.510796e+09
# Xcel Energy, Inc.                 LGJNMI9GH8XIDG5RCM61 US98389B1008  5.044800e+10
# Balfour Beatty                    CT4UIJ3TUKGYYHMENQ17 GB0000961622  4.846000e+09
# CBRE                              52990016II9MJ2OSWA10 US12504L1098  2.207300e+10
#
# [76 rows x 13 columns]

# %%
production_cols = [c for c in itr_sheet.columns if c.endswith('production')]
metrics_cols = ['emissions_metric', 'production_metric']

# %% [markdown]
# Insert an empty column so we can make it easy to add PDF references by hand

# %%
df = itr_sheet.copy ()
df['2021_pdf'] = ''

# %% [markdown]
# The fundamental wide-to-long transformation that makes data look so much more beautiful

# %%
df = pd.wide_to_long(df.loc[:, ~df.columns.isin(financial_cols)],
                     stubnames=[str(s) for s in list(range(2016,2023))],
                     i=index_cols, j='metric', sep='_', suffix=r'.*').dropna(how='all', axis=1)
df = df.rename(index={f"ghg_{scope}":scope for scope in scopes}).reset_index('metric')
df.insert(df.columns.get_loc('metric'), 'sub_metric',
          df.apply(lambda x: 'location' if 's2' in x.metric else 'combined' if x.metric=='s3' else '', axis=1))
df.insert(df.columns.get_loc('metric')+1, 'unit',
          df.apply(lambda x: x.production_metric if x.metric=='production' else '' if x.metric=='pdf' else x.emissions_metric, axis=1))
df.drop(columns=['production_metric', 'emissions_metric'], inplace=True)
df.insert(df.columns.get_loc('unit')+1, 'report_date', date(2021, 12, 31))
df.loc[df.metric=='pdf', df.columns[df.columns.get_loc('unit')+1]:df.columns[-1]] = ''
df = df.set_index('metric', append=True)
df.columns = df.columns.map(lambda x: int(x) if x[0].isnumeric() else x)
esg_df = df
display(esg_df.iloc[0:10])
# Out:
#                                                           sub_metric    unit  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1                      t CO2
#                                                s2           location   t CO2
#                                                s1s2         location   t CO2
#                                                s3           combined   t CO2
#                                                production                GWh
#                                                pdf
# ALLETE, Inc. 549300NNLSIMY6Z8OT86 US0185223007 s1                     Mt CO2
#                                                s2           location  Mt CO2
#                                                s1s2         location  Mt CO2
#                                                s3           combined  Mt CO2
#
#                                                           report_date  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          2021-12-31
#                                                s2          2021-12-31
#                                                s1s2        2021-12-31
#                                                s3          2021-12-31
#                                                production  2021-12-31
#                                                pdf
# ALLETE, Inc. 549300NNLSIMY6Z8OT86 US0185223007 s1          2021-12-31
#                                                s2          2021-12-31
#                                                s1s2        2021-12-31
#                                                s3          2021-12-31
#
#                                                                  2016  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          70457000.0
#                                                s2            306000.0
#                                                s1s2        70763000.0
#                                                s3           5864000.0
#                                                production    104312.0
#                                                pdf
# ALLETE, Inc. 549300NNLSIMY6Z8OT86 US0185223007 s1            8.028792
#                                                s2                 0.0
#                                                s1s2          8.028792
#                                                s3                 NaN
#
#                                                                  2017  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          59804000.0
#                                                s2            220000.0
#                                                s1s2        60024000.0
#                                                s3          13871800.0
#                                                production    94148.97
#                                                pdf
# ALLETE, Inc. 549300NNLSIMY6Z8OT86 US0185223007 s1             6.56607
#                                                s2                 0.0
#                                                s1s2           6.56607
#                                                s3                 NaN
#
#                                                                  2018  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          50291000.0
#                                                s2            314000.0
#                                                s1s2        50605000.0
#                                                s3          10071100.0
#                                                production    83985.94
#                                                pdf
# ALLETE, Inc. 549300NNLSIMY6Z8OT86 US0185223007 s1            6.622019
#                                                s2                 0.0
#                                                s1s2          6.622019
#                                                s3                 NaN
#
#                                                                  2019  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          45611000.0
#                                                s2            324000.0
#                                                s1s2        45935000.0
#                                                s3           9973200.0
#                                                production   75904.355
#                                                pdf
# ALLETE, Inc. 549300NNLSIMY6Z8OT86 US0185223007 s1            4.223366
#                                                s2                 0.0
#                                                s1s2          4.223366
#                                                s3                 NaN
#
#                                                                  2020  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          42961000.0
#                                                s2            254000.0
#                                                s1s2        43215000.0
#                                                s3           7269200.0
#                                                production   75271.522
#                                                pdf
# ALLETE, Inc. 549300NNLSIMY6Z8OT86 US0185223007 s1            3.750732
#                                                s2                 0.0
#                                                s1s2          3.750732
#                                                s3                 NaN
#
#                                                                  2021
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          41202392.0
#                                                s2            253302.0
#                                                s1s2        41455694.0
#                                                s3           7351038.0
#                                                production   72506.148
#                                                pdf
# ALLETE, Inc. 549300NNLSIMY6Z8OT86 US0185223007 s1            4.223366
#                                                s2                 0.0
#                                                s1s2          4.223366
#                                                s3                 NaN

# %% [markdown]
# Define a helper function to estimate how wide to make each column

# %%
def get_cell_width(x, na_action='error'):
    if isinstance(x, float):
        if x > 0:
            return log10(x)+1
        else:
            return 12
    if pd.isna(x):
        return 2
    return len(str(x))

# %% [markdown]
# Put pandas values into new worksheet(s).
#
# First up, the fundamental financial data

# %%
old_sheet='ITR input data'
new_sheet='ITR V2 input data'

df = financial_df
df.to_excel(xlsx_writer, sheet_name=new_sheet)
# resetting the index after writing the dataframe lets us adjust width and keep column consistency with column-based Excel things
df = df.reset_index()
financial_ws = xlsx_writer.sheets[new_sheet]
dim_holder = DimensionHolder(worksheet=financial_ws)
financial_fill = wb_xlsx[old_sheet].cell(row=1,column=1).fill.copy()

# Then make the worksheet pretty
for i, col in enumerate(df.columns):
    if col=='report_date':
        # We fudge the width with number_format that `str(datetime)` doesn't understand
        dim_holder[get_column_letter(i+1)] = ColumnDimension(financial_ws, min=i+1, max=i+1, width=len(col)+2)
    else:
        dim_holder[get_column_letter(i+1)] = ColumnDimension(
            financial_ws, min=i+1, max=i+1,
            width=max(df.iloc[:, i].map(lambda x: len(str(x))).max()+2*(col=='company_lei'),
                      len(col))+2)
    if i<=2:
        # Format index columns
        for j in range(1, financial_ws.max_row+1):
            financial_ws.cell(column=i+1, row=j).alignment = Alignment(horizontal='left', vertical='center')
    else:
        if col=='report_date':
            for j in range(1, financial_ws.max_row+1):
                financial_ws.cell(row=j, column=i+1).number_format = 'yyyy-mm-dd'
        financial_ws.cell(column=i+1, row=1).fill = financial_fill

financial_ws.column_dimensions = dim_holder

# Lighten the Region column, which is optional
region_col_letter = get_column_letter(df.columns.get_loc('region')+1)
for cell in financial_ws[f"{region_col_letter}1:{region_col_letter}{financial_ws.max_row}"]:
    cell[0].font = cell[0].font.copy(color=Color('FF888888'))
# Out:
# /var/folders/lf/r0g8y7yj4rn56tq1_5g2hln00000gq/T/ipykernel_31462/4020000820.py:10: DeprecationWarning: Call to deprecated function copy (Use copy(obj) or cell.obj = cell.obj + other).
#   financial_fill = wb_xlsx[old_sheet].cell(row=1,column=1).fill.copy()
# /var/folders/lf/r0g8y7yj4rn56tq1_5g2hln00000gq/T/ipykernel_31462/4020000820.py:37: DeprecationWarning: Call to deprecated function copy (Use copy(obj) or cell.obj = cell.obj + other).
#   cell[0].font = cell[0].font.copy(color=Color('FF888888'))

# %% [markdown]
# Next up, the ESG data

# %%
new_sheet='ITR V2 esg data'
df = esg_df
df.to_excel(xlsx_writer, sheet_name=new_sheet)
# resetting the index after writing the dataframe lets us adjust width and keep column consistency with column-based Excel things
df = df.reset_index()
esg_ws = xlsx_writer.sheets[new_sheet]
dim_holder = DimensionHolder(worksheet=esg_ws)
thin_border = Border(left=Side(style='thin', color='FFC6C6C6'), 
                     right=Side(style='thin', color='FFC6C6C6'), 
                     top=Side(style='thin', color='FFC6C6C6'), 
                     bottom=Side(style='thin', color='FFC6C6C6'))

# We have only one cell to color, so it's not in the loop
esg_ws.cell(column=df.columns.get_loc('unit')+1, row=1).fill = wb_xlsx[old_sheet].cell(
    column=itr_sheet.columns.get_loc('emissions_metric')+1, row=1).fill.copy()

# Make worksheet pretty
for i, col in enumerate(df.columns):
    if col=='report_date':
        # We fudge the width with number_format that `str(datetime)` doesn't understand
        dim_holder[get_column_letter(i+1)] = ColumnDimension(financial_ws, min=i+1, max=i+1, width=len(col)+2)
    else:
        dim_holder[get_column_letter(i+1)] = ColumnDimension(
            esg_ws, min=i+1, max=i+1,
            width=max(df.iloc[:, i].map(get_cell_width).max()+2*(col=='company_lei'),
                      len(str(col)))+2)
    if i<=2:
        # Format index columns
        for j in range(1, esg_ws.max_row+1):
            esg_ws.cell(column=i+1, row=j).alignment = Alignment(horizontal='left', vertical='center')
    elif col=='report_date':
        for j in range(1, esg_ws.max_row+1):
            esg_ws.cell(row=j, column=i+1).number_format = 'yyyy-mm-dd'
    elif col in range(2016, 2323):
        column_color = 'EEEEEE' if (col % 2) == 0 else 'FFFFFF'
        for j in range(1, esg_ws.max_row+1):
            esg_ws.cell(column=i+1, row=j).fill = PatternFill("solid", start_color=column_color)
            esg_ws.cell(column=i+1, row=j).border = thin_border

esg_ws.column_dimensions = dim_holder
# Out:
# /var/folders/lf/r0g8y7yj4rn56tq1_5g2hln00000gq/T/ipykernel_31462/3130013065.py:14: DeprecationWarning: Call to deprecated function copy (Use copy(obj) or cell.obj = cell.obj + other).
#   esg_ws.cell(column=df.columns.get_loc('unit')+1, row=1).fill = wb_xlsx[old_sheet].cell(

# %%
xlsx_writer.save()

# %% [markdown]
# Show how to read the data back, and what it looks like

# %%
x = pd.read_excel(template_data_path_v2, sheet_name='ITR V2 esg data', index_col=[0, 1, 2, 3])
display(x)
# Out:
#                                                           sub_metric   unit  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1                NaN  t CO2
#                                                s2           location  t CO2
#                                                s1s2         location  t CO2
#                                                s3           combined  t CO2
#                                                production        NaN    GWh
# ...                                                              ...    ...
# CBRE         52990016II9MJ2OSWA10 US12504L1098 s2           location  t CO2
#                                                s1s2         location  t CO2
#                                                s3           combined  t CO2
#                                                production        NaN  ft**2
#                                                pdf               NaN    NaN
#
#                                                           report_date  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          2021-12-31
#                                                s2          2021-12-31
#                                                s1s2        2021-12-31
#                                                s3          2021-12-31
#                                                production  2021-12-31
# ...                                                               ...
# CBRE         52990016II9MJ2OSWA10 US12504L1098 s2          2021-12-31
#                                                s1s2        2021-12-31
#                                                s3          2021-12-31
#                                                production  2021-12-31
#                                                pdf                NaT
#
#                                                                    2016  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          7.045700e+07
#                                                s2          3.060000e+05
#                                                s1s2        7.076300e+07
#                                                s3          5.864000e+06
#                                                production  1.043120e+05
# ...                                                                 ...
# CBRE         52990016II9MJ2OSWA10 US12504L1098 s2          2.967800e+04
#                                                s1s2        9.309200e+04
#                                                s3          1.695400e+04
#                                                production  5.300000e+09
#                                                pdf                  NaN
#
#                                                                    2017  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          5.980400e+07
#                                                s2          2.200000e+05
#                                                s1s2        6.002400e+07
#                                                s3          1.387180e+07
#                                                production  9.414897e+04
# ...                                                                 ...
# CBRE         52990016II9MJ2OSWA10 US12504L1098 s2          2.501000e+04
#                                                s1s2        7.106700e+04
#                                                s3          1.862600e+04
#                                                production  5.500000e+09
#                                                pdf                  NaN
#
#                                                                    2018  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          5.029100e+07
#                                                s2          3.140000e+05
#                                                s1s2        5.060500e+07
#                                                s3          1.007110e+07
#                                                production  8.398594e+04
# ...                                                                 ...
# CBRE         52990016II9MJ2OSWA10 US12504L1098 s2          2.443900e+04
#                                                s1s2        7.050800e+04
#                                                s3          1.998400e+04
#                                                production  6.000000e+09
#                                                pdf                  NaN
#
#                                                                    2019  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          4.561100e+07
#                                                s2          3.240000e+05
#                                                s1s2        4.593500e+07
#                                                s3          9.973200e+06
#                                                production  7.590435e+04
# ...                                                                 ...
# CBRE         52990016II9MJ2OSWA10 US12504L1098 s2          2.802000e+04
#                                                s1s2        8.679000e+04
#                                                s3          5.830793e+07
#                                                production  6.800000e+09
#                                                pdf                  NaN
#
#                                                                    2020  \
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          4.296100e+07
#                                                s2          2.540000e+05
#                                                s1s2        4.321500e+07
#                                                s3          7.269200e+06
#                                                production  7.527152e+04
# ...                                                                 ...
# CBRE         52990016II9MJ2OSWA10 US12504L1098 s2          2.264400e+04
#                                                s1s2        8.302300e+04
#                                                s3          5.468473e+07
#                                                production  7.000000e+09
#                                                pdf                  NaN
#
#                                                                    2021
# company_name company_lei          company_id   metric
# AES Corp.    2NUNNB7D43COUIRE5295 US00130H1059 s1          4.120239e+07
#                                                s2          2.533020e+05
#                                                s1s2        4.145569e+07
#                                                s3          7.351038e+06
#                                                production  7.250615e+04
# ...                                                                 ...
# CBRE         52990016II9MJ2OSWA10 US12504L1098 s2          1.984700e+04
#                                                s1s2        6.609800e+04
#                                                s3          8.916877e+07
#                                                production  7.100000e+09
#                                                pdf                  NaN
#
# [456 rows x 9 columns]
